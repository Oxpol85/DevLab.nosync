# %% [markdown]
# > # 📓 Plantilla de Estudio:
#
# ## 🎯 _Objetivo de la Sesión_
#
# -

# %% [markdown]
# > # 📖 Notas (Markdown)
#
# -
#
# ### **Concepto Clave**
#
# -
#
# -
#
# • Tip: itálica siempre

# %% [markdown]
# > # 💻 Laboratorio de Código (Celda de Código en .ipynb)
#
# ```
# def main():
#     print("Hello, world!")
# if __name__ == "__main__":
#     main()
#
# ```

# %% [markdown]
# > # ⚠️ Errores y Soluciones
# >
# > • Error: `NameError: name 'x' is not defined`
#
# • Solución: Olvidé declarar la variable antes del loop.

# %% [markdown]
# > # ✅ Conclusiones para el README
# >
# > `Resume aquí lo que moverás a tu documentación final.`
